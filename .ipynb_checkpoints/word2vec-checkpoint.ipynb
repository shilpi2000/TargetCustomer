# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import wget
import re
Agressive = []
NonAgressive = []
MidAgressive=[]
label_names = ['Agressive', 'NonAgressive','MidAgressive']
num_epochs = 5
batch_size = 40

# %%
pip freeze
# Out:
# absl-py==0.7.1
# asn1crypto==1.3.0
# astor==0.8.0
# astroid==2.2.5
# attrs==19.1.0
# autopep8==1.4.4
# backcall==0.1.0
# beautifulsoup4==4.8.0
# bleach==3.1.0
# boto==2.49.0
# boto3==1.12.0
# botocore==1.15.0
# bs4==0.0.1
# bz2file==0.98
# cachetools==3.1.1
# certifi==2019.6.16
# cffi==1.14.0
# chardet==3.0.4
# Click==7.0
# colorama==0.4.1
# cryptography==2.7
# cx-Freeze==6.0
# cycler==0.10.0
# Cython==0.29.14
# decorator==4.4.0
# defusedxml==0.6.0
# distro==1.4.0
# docutils==0.15.2
# entrypoints==0.3
# enum34==1.1.6
# filelock==3.0.12
# Flask==1.1.1
# future==0.18.2
# gast==0.2.2
# gensim==3.8.0
# google-auth==1.7.0
# google-auth-oauthlib==0.4.1
# google-pasta==0.1.8
# grpcio==1.16.1
# gTTS==2.0.3
# gTTS-token==1.1.3
# h5py==2.8.0
# idna==2.8
# imageio==2.6.0
# implicit==0.4.0
# imutils==0.5.3
# ipykernel==5.1.4
# ipynb-py-convert==0.4.5
# ipython==7.7.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.20
# itsdangerous==1.1.0
# jedi==0.13.3
# Jinja2==2.10.1
# jmespath==0.9.4
# joblib==0.13.2
# jsonschema==3.0.1
# jupyter-client==6.1.2
# jupyter-core==4.6.3
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# Kivy==1.11.1
# kivy-deps.glew==0.1.12
# kivy-deps.gstreamer==0.1.17
# kivy-deps.sdl2==0.1.22
# Kivy-Garden==0.1.4
# kiwisolver==1.1.0
# lazy-object-proxy==1.4.1
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.2
# mccabe==0.6.1
# mistune==0.8.4
# mkl-fft==1.0.12
# mkl-random==1.0.2
# mkl-service==2.0.2
# mock==3.0.5
# mtcnn==0.0.9
# mysql==0.0.2
# mysql-connector==2.2.9
# mysqlclient==1.4.6
# nbconvert==5.5.0
# nbformat==4.4.0
# nltk==3.4.5
# notebook==6.0.3
# np-utils==0.5.12.1
# numpy==1.17.3
# oauthlib==3.1.0
# olefile==0.46
# opt-einsum==3.1.0
# pandas==1.0.1
# pandocfilters==1.4.2
# parso==0.5.0
# pickleshare==0.7.5
# Pillow==6.1.0
# prettytensor==0.7.4
# prometheus-client==0.7.1
# prompt-toolkit==2.0.9
# protobuf==3.8.0
# pyasn1==0.4.7
# pyasn1-modules==0.2.7
# pycodestyle==2.5.0
# pycparser==2.19
# Pygments==2.4.2
# pylint==2.3.1
# pyOpenSSL==19.0.0
# pyparsing==2.4.0
# PyPDF2==1.26.0
# pypiwin32==223
# PyQt5==5.12.3
# PyQt5-sip==4.19.18
# PyQtWebEngine==5.12.1
# pyrsistent==0.14.11
# PySocks==1.7.1
# python-dateutil==2.8.1
# pytorch-transformers==1.2.0
# pytz==2019.1
# pywin32==227
# pywinpty==0.5.5
# PyYAML==5.1.1
# pyzmq==18.0.0
# regex==2020.2.20
# requests==2.22.0
# requests-oauthlib==1.3.0
# rsa==4.0
# s3transfer==0.3.3
# sacremoses==0.0.38
# scikit-learn==0.21.2
# scipy==1.2.0
# selenium==3.141.0
# Send2Trash==1.5.0
# sentencepiece==0.1.85
# six==1.12.0
# smart-open==1.9.0
# soupsieve==1.9.2
# tabula-py==2.1.0
# tensorboard==2.0.1
# tensorflow==2.0.0
# tensorflow-estimator==2.0.1
# tensorflow-gpu==2.0.0
# tensorflow-hub==0.8.0
# termcolor==1.1.0
# terminado==0.8.2
# testpath==0.4.2
# tflearn==0.3.2
# tokenizers==0.5.2
# torch==1.3.1
# tornado==6.0.3
# tqdm==4.32.1
# traitlets==4.3.2
# transformers==2.7.0
# typed-ast==1.3.5
# urllib3==1.25.8
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.15.4
# wget==3.2
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# wincertstore==0.2
# wrapt==1.11.1
# xlrd==1.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Could not generate requirement for distribution -cipy 1.3.0 (d:\anaconda\envs\myenv\lib\site-packages): Parse error at "'-cipy==1'": Expected W:(abcd...)

# %%
#downloading the pretrained word2vec model
import requests
url = "https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz"
myfile = requests.get(url)
open('./GoogleNews-vectors-negative300.bin.gz', 'wb').write(myfile.content)

# %%
def readDataFrame():
    #loading the dataset into the dataframe
    df=pd.read_csv("agr_en_train.csv")
    #changing the name of the columns
    df=df.rename(columns={"Well said sonu..you have courage to stand against dadagiri of Muslims": "Sentence", "OAG": "Label"})
    #deleting a row which is not essential for the model
    df.drop(columns="facebook_corpus_msr_1723796",inplace=True)
    return df

def cleanData():
    for i in range(len(df)):
        #replacing the categorical label to numeric label
        if df["Label"][i]=="NAG":
            df["Label"][i]=0
        if df["Label"][i]=="CAG":
            df["Label"][i]=1
        if df["Label"][i]=="OAG":
            df["Label"][i]=2 #converting the value of the label to two distinct type AGRESSIVE OR NON AGRESSIVE

    for i in range(len(df)):
        #using regex library to clean the dataset and convert each character to lowercase
        df["Sentence"][i]=re.sub('[^a-zA-Z]',' ', df["Sentence"][i])
        df["Sentence"][i]= df["Sentence"][i].lower()

# %%
#call the readDataFrame to intialize the data into the dataframe 
df=readDataFrame()
df.head()
# Out:
#                                             Sentence Label
# 0  Most of Private Banks ATM's Like HDFC, ICICI e...   NAG
# 1     Now question is, Pakistan will adhere to this?   OAG
# 2  Pakistan is comprised of fake muslims who does...   OAG
# 3  ??we r against cow slaughter,so of course it w...   NAG
# 4  Wondering why Educated Ambassador is strugglin...   CAG

# %%
#call the cleanData to process the data 
cleanData()
df.head()
# Out:
#                                             Sentence Label
# 0  most of private banks atm s like hdfc  icici e...     0
# 1     now question is  pakistan will adhere to this      2
# 2  pakistan is comprised of fake muslims who does...     2
# 3    we r against cow slaughter so of course it w...     0
# 4  wondering why educated ambassador is strugglin...     1

# %%
# For tokenizing the sencences for data modelling
from nltk import word_tokenize
tokens = [word_tokenize(sentence) for sentence in df.Sentence]
def lowTocken(tokens): 
    return [w.lower() for w in tokens]    
lowTockens = [lowTocken(tokens) for tokens in tokens]

# %%
from nltk.corpus import stopwords
#storing the stopwords from the nltk library to remove them from the dataset
stoplist = stopwords.words('english')
def removeStopWords(tokens): 
    return [word for word in tokens if word not in stoplist]
filtered_words = [removeStopWords(sen) for sen in lowTockens]
df['Sentence'] = [' '.join(sen) for sen in filtered_words]
#adding the token column into the dataframe 
df['tokens'] = filtered_words
df.head()
# Out:
#                                             Sentence Label  \
# 0  private banks atm like hdfc icici etc cash pub...     0
# 1                           question pakistan adhere     2
# 2  pakistan comprised fake muslims know meaning u...     2
# 3  r cow slaughter course stop leather manufactur...     0
# 4  wondering educated ambassador struggling pay c...     1
#
#                                               tokens
# 0  [private, banks, atm, like, hdfc, icici, etc, ...
# 1                       [question, pakistan, adhere]
# 2  [pakistan, comprised, fake, muslims, know, mea...
# 3  [r, cow, slaughter, course, stop, leather, man...
# 4  [wondering, educated, ambassador, struggling, ...

# %%
#seperating the label into two distinct rows Agressive and nonAgressive
for m in df.Label:
    if m == 0:
        #adding 1 to nonAgressive if the label value is 0
        NonAgressive.append(1)
        #adding 0 to Agressive if the label value is 0
        Agressive.append(0)
        #adding 0 to MidAgressive if the label value is 0
        MidAgressive.append(0)
    elif m==1:
        #adding 0 to nonAgressive if the label value is 0
        NonAgressive.append(0)
        #adding 1 to MidAgressive if the label value is 1
        MidAgressive.append(1)
        #adding 0 to Agressive if the label value is 0
        Agressive.append(0)
    else:
       #adding 0 to nonAgressive if the label value is 0
        NonAgressive.append(0)
        #adding 1 to MidAgressive if the label value is 0
        MidAgressive.append(0)
        #adding 0 to Agressive if the label value is 1
        Agressive.append(1) 

# adding the two created columns to the dataset
df['NonAgressive']= NonAgressive
df['MidAgressive']=MidAgressive
df['Agressive']= Agressive

df = df[['Sentence', 'tokens', 'Label',  'NonAgressive','MidAgressive','Agressive']]
df.head()
# Out:
#                                             Sentence  \
# 0  private banks atm like hdfc icici etc cash pub...
# 1                           question pakistan adhere
# 2  pakistan comprised fake muslims know meaning u...
# 3  r cow slaughter course stop leather manufactur...
# 4  wondering educated ambassador struggling pay c...
#
#                                               tokens Label  NonAgressive  \
# 0  [private, banks, atm, like, hdfc, icici, etc, ...     0             1
# 1                       [question, pakistan, adhere]     2             0
# 2  [pakistan, comprised, fake, muslims, know, mea...     2             0
# 3  [r, cow, slaughter, course, stop, leather, man...     0             1
# 4  [wondering, educated, ambassador, struggling, ...     1             0
#
#    MidAgressive  Agressive
# 0             0          0
# 1             0          1
# 2             0          1
# 3             0          0
# 4             1          0

# %%
from sklearn.model_selection import train_test_split
# importing train test split inorder to create training and testing data
data_train, data_test = train_test_split(df, 
                                         test_size=0.30, 
                                         random_state=30)
from gensim import models
#importing models from gensim library to load the word2vec model
word2vec_path = 'GoogleNews-vectors-negative300.bin.gz'
word2vec = models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
#creating the training words from the token column  of the dataframe
trainingWord = [word for tokens in data_train["tokens"] for word in tokens]
#converting the training word variable to a list of not repeating words and then sorting the list 
trainVoc = sorted(list(set(trainingWord)))
#creating the testing words from the token column of the dataframe 
testingWord = [word for tokens in data_test["tokens"] for word in tokens]
#converting the testing list into a list of non repeating elements and sorting then in order
testing_vocab = sorted(list(set(testingWord)))
#initializing the max length of the sentence to be fed into the dataset
MaxSeqLength = 40
#initializing the dimension of the neural network model
em_dim = 300
#tokenizing the training vocab 
tokenizer = Tokenizer(num_words=len(trainVoc), lower=True, char_level=False)
tokenizer.fit_on_texts(data_train["Sentence"].tolist())
trainingSeq = tokenizer.texts_to_sequences(data_train["Sentence"].tolist())
train_word_index = tokenizer.word_index
train_cnn_data = pad_sequences(trainingSeq,maxlen=MaxSeqLength)

# %%
trainEmbeddingWeight = np.zeros((len(train_word_index)+1, em_dim))
for word,index in train_word_index.items():
    trainEmbeddingWeight[index,:] = word2vec[word] if word in word2vec else np.random.rand(em_dim)
test_sequences = tokenizer.texts_to_sequences(data_test["Sentence"].tolist())
test_cnn_data = pad_sequences(test_sequences, maxlen=MaxSeqLength)

# %%
def createNetwork(embed, seqLen, count, emDim, IndLable, optimizerVal):
    
    #initializing the embedding layer as the first layer
    Em_layer = Embedding(count,emDim,weights=[embed],input_length=seqLen,trainable=False)
    seq_Input = Input(shape=(seqLen,), dtype='int32')
    embedded_sequences = Em_layer(seq_Input)
    convo = []
    #loop to create multilayer of convo1D and max pooling layer
    filterSize = [1,3,5]
    for filter_size in filterSize:
        #creating convo1D layer with 300 filters and activation as relu
        lConv = tf.keras.layers.Conv1D(filters=300, kernel_size=filter_size, activation='relu')(embedded_sequences)
        l_pool = tf.keras.layers.GlobalMaxPooling1D()(lConv)
        convo.append(l_pool)
    l_merge = concatenate(convo, axis=1)
    #creating dropout layer
    x = Dropout(0.1)(l_merge)  
    #creating dense layer
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.2)(x)
    preds = tf.keras.layers.Dense(IndLable, activation='softmax')(x)
    model = Model(seq_Input, preds)
    model.compile(loss='sparse_categorical_crossentropy',optimizer=optimizerVal,metrics=['acc'])
    model.summary()
    return model

# %%
from __future__ import division, print_function
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Reshape, Flatten, concatenate, Input, Conv1D, GlobalMaxPooling1D, Embedding
y_train = data_train[label_names].values

x_train = train_cnn_data
y_tr = y_train
model1 = createNetwork(trainEmbeddingWeight, MaxSeqLength, len(train_word_index)+1, em_dim, 
                len(list(label_names)),'adam')
model2 = createNetwork(trainEmbeddingWeight, MaxSeqLength, len(train_word_index)+1, em_dim, 
                len(list(label_names)),'rmsprop')
model3 = createNetwork(trainEmbeddingWeight, MaxSeqLength, len(train_word_index)+1, em_dim, 
                len(list(label_names)),'ftrl')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 40)]         0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 40, 300)      5136900     input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 40, 300)      90300       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 38, 300)      270300      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 36, 300)      450300      embedding_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_3 (GlobalM (None, 300)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 300)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 300)          0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 900)          0           global_max_pooling1d_3[0][0]
#                                                                  global_max_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 900)          0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          115328      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 3)            387         dropout_3[0][0]
# ==================================================================================================
# Total params: 6,063,515
# Trainable params: 926,615
# Non-trainable params: 5,136,900
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 40)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 40, 300)      5136900     input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 40, 300)      90300       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 38, 300)      270300      embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 36, 300)      450300      embedding_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 300)          0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 300)          0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_8 (GlobalM (None, 300)          0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 900)          0           global_max_pooling1d_6[0][0]
#                                                                  global_max_pooling1d_7[0][0]
#                                                                  global_max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 900)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          115328      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            387         dropout_5[0][0]
# ==================================================================================================
# Total params: 6,063,515
# Trainable params: 926,615
# Non-trainable params: 5,136,900
# __________________________________________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 40)]         0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 40, 300)      5136900     input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 40, 300)      90300       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 38, 300)      270300      embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 36, 300)      450300      embedding_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 300)          0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_10 (Global (None, 300)          0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_11 (Global (None, 300)          0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 900)          0           global_max_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_10[0][0]
#                                                                  global_max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 900)          0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          115328      dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 3)            387         dropout_7[0][0]
# ==================================================================================================
# Total params: 6,063,515
# Trainable params: 926,615
# Non-trainable params: 5,136,900
# __________________________________________________________________________________________________

# %%
def change_to_right(wrong_labels):
    right_labels=[]
    for x in wrong_labels:
        for i in range(0,len(wrong_labels[0])):
            if x[i]==1:
                right_labels.append(i)
    return right_labels
y_train = data_train[label_names].values
x_train = train_cnn_data
x_test=x_train[1:1001]
y_tr = tf.convert_to_tensor(np.array(change_to_right(y_train)))

# %%
y_test=[]
np.argmax(y_train[0])
for i in y_train[0:1000]:
    y_test.append(np.argmax(i))

# %%
#training the cnn model with the data provided
hist = model1.fit(x_train, y_tr, epochs=num_epochs, validation_split=0.2, shuffle=True, batch_size=batch_size)
hist1 = model2.fit(x_train, y_tr, epochs=num_epochs, validation_split=0.2, shuffle=True, batch_size=batch_size)
hist2= model3.fit(x_train, y_tr, epochs=num_epochs, validation_split=0.2, shuffle=True, batch_size=batch_size)
predictions = model1.predict(test_cnn_data, batch_size=1024, verbose=1)
predictions1 = model2.predict(test_cnn_data, batch_size=1024, verbose=1)
predictions2 = model3.predict(test_cnn_data, batch_size=1024, verbose=1)
labels = [0,1,2]
prediction_labels=[]
prediction_labels1=[]
prediction_labels2=[]
for p in predictions:
    prediction_labels.append(labels[np.argmax(p)])
for p in predictions1:
    prediction_labels1.append(labels[np.argmax(p)])
for p in predictions2:
    prediction_labels2.append(labels[np.argmax(p)])
# Out:
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...

# %%
plt.plot(hist.history['acc'],)
plt.plot(hist1.history['acc'])
plt.legend(["accuracy using adam optimizer", "accuracy using rmsprop optimizer"], loc ="lower right")
# plt.plot(hist2.history['acc'])

# %%
plt.plot(hist.history['loss'])
plt.plot(hist1.history['loss'])
plt.legend(["loss using adam optimizer", "loss using rmsprop optimizer"], loc ="top right")
# plt.plot(hist2.history['loss'])

# %%
plt.plot(hist.history["val_acc"])
plt.plot(hist1.history["val_acc"])
plt.legend(["validation acc using adam optimizer", "validation acc using rmsprop optimizer"], loc ="top right")
# plt.plot(hist2.history["val_acc"])

# %%
pred=model1.predict(x_test)
pred1=model2.predict(x_test)
pred2=model3.predict(x_test)
pred[0]
# Out:
# array([1.7418502e-05, 9.9974698e-01, 2.3558503e-04], dtype=float32)

# %%
#accuracy evaluation of model with adam optimizer
predec=[]
for i in pred:
    predec.append(np.argmax(i))
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
#printing the confusion matrix and the accuracy score to ecaluate model
results = confusion_matrix(predec, y_test) 
print(results) 
print(accuracy_score(predec, y_test))
print(classification_report(predec, y_test))
# Out:
# [[ 59  72  91]
#  [ 92 179 139]
#  [ 77 157 134]]
# 0.372
#               precision    recall  f1-score   support
#
#            0       0.26      0.27      0.26       222
#            1       0.44      0.44      0.44       410
#            2       0.37      0.36      0.37       368
#
#     accuracy                           0.37      1000
#    macro avg       0.36      0.36      0.36      1000
# weighted avg       0.37      0.37      0.37      1000

# %%
#accuracy evaluation of model with rmsprop optimizer
predec=[]
for i in pred1:
    predec.append(np.argmax(i))
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
#printing the confusion matrix and the accuracy score to ecaluate model
results = confusion_matrix(predec, y_test) 
print(results) 
print(accuracy_score(predec, y_test))
print(classification_report(predec, y_test))
# Out:
# [[ 61  73  91]
#  [ 90 176 143]
#  [ 77 159 130]]
# 0.367
#               precision    recall  f1-score   support
#
#            0       0.27      0.27      0.27       225
#            1       0.43      0.43      0.43       409
#            2       0.36      0.36      0.36       366
#
#     accuracy                           0.37      1000
#    macro avg       0.35      0.35      0.35      1000
# weighted avg       0.37      0.37      0.37      1000

# %%
#accuracy evaluation of model with ftrl optimizer
predec=[]
for i in pred2:
    predec.append(np.argmax(i))
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
#printing the confusion matrix and the accuracy score to ecaluate model
results = confusion_matrix(predec, y_test) 
print(results) 
print(accuracy_score(predec, y_test))
print(classification_report(predec, y_test))
# Out:
# [[  0   0   0]
#  [228 408 364]
#  [  0   0   0]]
# 0.408
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.41      0.58      1000
#            2       0.00      0.00      0.00         0
#
#     accuracy                           0.41      1000
#    macro avg       0.33      0.14      0.19      1000
# weighted avg       1.00      0.41      0.58      1000
